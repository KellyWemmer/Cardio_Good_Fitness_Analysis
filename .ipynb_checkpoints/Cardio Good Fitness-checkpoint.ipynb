# %% [markdown]
# Data was downloaded from https://www.kaggle.com/saurav9786/cardiogoodfitness
#
# Column info:
#
# product purchased, TM195, TM498, or TM798;
#
# gender;
#
# age, in years;
#
# education, in years;
#
# relationship status, single or partnered;
#
# annual household income ($);
#
# average number of times the customer plans to use the treadmill each week;
#
# average number of miles the customer expects to walk/run each week;
#
# self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("CardioGoodFitness.csv")
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# ### Univariate Exploration

# %%
df.Product.hist()
plt.title('Histogram of Types of Treadmills purchased')
plt.xlabel('Treadmill Model')
plt.ylabel('Count');

# %%
df.Age.hist()
plt.title('Ages of People who Bought Treadmills')
plt.xlabel('Age')
plt.ylabel('Count');

# %%
df.Gender.hist()
plt.title('Gender of People who Bought Treadmills')
plt.xlabel('Gender')
plt.ylabel('Count');

# %%
df.Education.hist()
plt.title('Education Level of People who Bought Treadmills')
plt.xlabel('Education Level')
plt.ylabel('Count');

# %%
df.MaritalStatus.hist()
plt.title('Marital Status of People who Bought Treadmills')
plt.xlabel('Marital Status')
plt.ylabel('Count');

# %%
df.Usage.hist()
plt.title('Weekly Usage of People who Bought Treadmills')
plt.xlabel('Usage')
plt.ylabel('Count');

# %%
df.Fitness.hist()
plt.title('Fitness Level of People who Bought Treadmills')
plt.xlabel('Fitness Level')
plt.ylabel('Count');

# %%
df.Income.hist()
plt.title('Annual Income of People who Bought Treadmills')
plt.xlabel('Income')
plt.ylabel('Count');

# %%
df.Miles.hist()
plt.title('Number of Miles per Week')
plt.xlabel('Miles')
plt.ylabel('Count');

# %% [markdown]
# ### Multivariate Exploration

# %%
sns.pairplot(df, hue='Product');
# Out:
# C:\Users\kelly\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\kelly\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Convert Categorical Variables

# %%
product = pd.get_dummies(df['Product'], drop_first=True)
gender=pd.get_dummies(df['Gender'], drop_first=True)
maritalstatus = pd.get_dummies(df['MaritalStatus'], drop_first=True)

# %%
#Drop unnecessary columns
df.drop(['Product','Gender','MaritalStatus'],axis=1,inplace=True)

# %%
#Want to evaluate TM498
df=pd.concat([df, product, gender, maritalstatus], axis=1)
df=df.drop('TM798', axis=1)
df.head()
# Out:
#    Age  Education  Usage  Fitness  Income  Miles  TM498  Male  Single
# 0   18         14      3        4   29562    112      0     1       1
# 1   19         15      2        3   31836     75      0     1       1
# 2   19         14      4        3   30699     66      0     0       0
# 3   19         12      3        3   32973     85      0     1       1
# 4   20         13      4        2   35247     47      0     1       0

# %%
#Move target to end of dataframe
df['TM498'] = df.pop('TM498')
df.head()
# Out:
#    Age  Education  Usage  Fitness  Income  Miles  Male  Single  TM498
# 0   18         14      3        4   29562    112     1       1      0
# 1   19         15      2        3   31836     75     1       1      0
# 2   19         14      4        3   30699     66     0       0      0
# 3   19         12      3        3   32973     85     1       1      0
# 4   20         13      4        2   35247     47     1       0      0

# %% [markdown]
# ### Train Test Split

# %%
#Train Test Split on TM498 model
from sklearn.model_selection import train_test_split

# %%
X = df[['Age', 'Education','Usage', 'Fitness', 'Income', 'Miles', 'Male', 'Single']]
y = df['TM498']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# ### Train and Fit

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ### Predictions

# %%
predictions = logmodel.predict(X_test)

# %% [markdown]
# ### Evaluations

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76        33
#            1       0.00      0.00      0.00        21
#
#     accuracy                           0.61        54
#    macro avg       0.31      0.50      0.38        54
# weighted avg       0.37      0.61      0.46        54
# C:\Users\kelly\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Using K Nearest Neighbors

# %%
#Standardize the variables
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
#Fit non target data
scaler.fit(df.drop('TM498', axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
#Center and scale objects
scaled_features = scaler.transform(df.drop('TM498', axis=1))

# %%
df_feats = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feats.head()
# Out:
#         Age  Education     Usage   Fitness    Income     Miles      Male  \
# 0 -1.558146  -0.974987 -0.421117  0.720443 -1.467585  0.170257  0.854850
# 1 -1.413725  -0.354854 -1.345520 -0.325362 -1.329438 -0.545143  0.854850
# 2 -1.413725  -0.974987  0.503286 -0.325362 -1.398512 -0.719159 -1.169795
# 3 -1.413725  -2.215254 -0.421117 -0.325362 -1.260365 -0.351792  0.854850
# 4 -1.269303  -1.595120  0.503286 -1.371166 -1.122218 -1.086527  0.854850
#
#      Single
# 0  1.210683
# 1  1.210683
# 2 -0.825980
# 3  1.210683
# 4 -0.825980

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features,df['TM498'],
                                                    test_size=0.30)

# %% [markdown]
# ### K Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %% [markdown]
# ### Predictions

# %%
pred = knn.predict(X_test)

# %% [markdown]
# ### Evaluations

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[23 12]
#  [14  5]]

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.66      0.64        35
#            1       0.29      0.26      0.28        19
#
#     accuracy                           0.52        54
#    macro avg       0.46      0.46      0.46        54
# weighted avg       0.51      0.52      0.51        54

# %% [markdown]
# ### Choosing a K Value

# %%
error_rate = []


for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
# NOW WITH K=26
knn = KNeighborsClassifier(n_neighbors=26)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=26')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=26
#
#
# [[35  0]
#  [18  1]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80        35
#            1       1.00      0.05      0.10        19
#
#     accuracy                           0.67        54
#    macro avg       0.83      0.53      0.45        54
# weighted avg       0.78      0.67      0.55        54
